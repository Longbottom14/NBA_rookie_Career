# %%
import requests
import os
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
standing_url ='https://hashtagbasketball.com/nba-rookie-rankings'

# %%
data_games = requests.get(standing_url)

# %%
soup_teams = BeautifulSoup(data_games.content, "html.parser")
teams_table = soup_teams.find("table",id="ContentPlaceHolder1_GridView1")

# %%
teams_table
# Out:
# <table border="1" cellspacing="0" class="table table-bordered text-left" id="ContentPlaceHolder1_GridView1" rules="all">
# <tr>
# ...

# %%
links_teams = teams_table.find_all("tr")#class_="table table-bordered text-left")

# %%
s = links_teams[1].find("td")#,id = )

# %%
matches_games = pd.read_html(data_games.text, match="table table-bordered text-left")[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9b89721c36c0> in <module>
# ----> 1 matches_games = pd.read_html(data_games.text, match="table table-bordered text-left")[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111     io = stringify_path(io)
#    1112
# -> 1113     return _parse(
#    1114         flavor=flavor,
#    1115         io=io,
#
# ...

# %%
id="ContentPlaceHolder1_GridView1"table table-bordered text-left
